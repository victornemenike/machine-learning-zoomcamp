# %% [markdown]
# # Homework 3: Machine Learning for Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile
import os

# %% [markdown]
# ## Dataset

# %%
#!wget https://archive.ics.uci.edu/static/public/222/bank+marketing.zip

# %%
"""
zip_file_path = "bank+marketing.zip"
extract_path = "bank_marketing"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

zip_file_path = "bank_marketing/bank.zip"
extract_path = "bank"

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
"""
# Out:
# '\nzip_file_path = "bank+marketing.zip"\nextract_path = "bank_marketing"\n\nwith zipfile.ZipFile(zip_file_path, \'r\') as zip_ref:\n    zip_ref.extractall(extract_path)\n\nzip_file_path = "bank_marketing/bank.zip"\nextract_path = "bank"\n\nwith zipfile.ZipFile(zip_file_path, \'r\') as zip_ref:\n    zip_ref.extractall(extract_path)\n'

# %%
df = pd.read_csv('bank/bank-full.csv',
                   sep=';', 
                   quotechar='"',
                   encoding='utf-8')
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.head().T
# Out:
#                     0           1             2            3        4
# age                58          44            33           47       33
# job        management  technician  entrepreneur  blue-collar  unknown
# marital       married      single       married      married   single
# education    tertiary   secondary     secondary      unknown  unknown
# default            no          no            no           no       no
# balance          2143          29             2         1506        1
# housing           yes         yes           yes          yes       no
# loan               no          no           yes           no       no
# contact       unknown     unknown       unknown      unknown  unknown
# day                 5           5             5            5        5
# month             may         may           may          may      may
# duration          261         151            76           92      198
# ...

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
selected_columns = ['age', 'job', 'marital', 'education',  'balance', 'housing',
                    'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
                    'previous', 'poutcome', 'y']

df_selected = df.copy()[selected_columns]
df_selected.head()
# Out:
#    age           job  marital  education  balance housing  contact  day month  \
# 0   58    management  married   tertiary     2143     yes  unknown    5   may
# 1   44    technician   single  secondary       29     yes  unknown    5   may
# 2   33  entrepreneur  married  secondary        2     yes  unknown    5   may
# 3   47   blue-collar  married    unknown     1506     yes  unknown    5   may
# 4   33       unknown   single    unknown        1      no  unknown    5   may
#
#    duration  campaign  pdays  previous poutcome   y
# 0       261         1     -1         0  unknown  no
# 1       151         1     -1         0  unknown  no
# 2        76         1     -1         0  unknown  no
# 3        92         1     -1         0  unknown  no
# 4       198         1     -1         0  unknown  no

# %%
df_selected.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ## Question 1
#
# What is the most frequent observation (mode) for the column education?

# %%
df_selected.education.mode()
# Out:
# 0    secondary
# Name: education, dtype: object

# %% [markdown]
# ## Question 2
#
# Create the correlation matrix for the numerical features of your dataset. In a correlation matrix, you compute the correlation coefficient between every pair of features.
#
# What are the two features that have the biggest correlation?

# %%
df_selected.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# balance       int64
# housing      object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
numerical = list(df_selected.dtypes[df_selected.dtypes == 'int64'].index)
numerical
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
df_selected[numerical].corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.097783 -0.009120 -0.004648  0.004760 -0.023758  0.001288
# balance   0.097783  1.000000  0.004503  0.021560 -0.014578  0.003435  0.016674
# day      -0.009120  0.004503  1.000000 -0.030206  0.162490 -0.093044 -0.051710
# duration -0.004648  0.021560 -0.030206  1.000000 -0.084570 -0.001565  0.001203
# campaign  0.004760 -0.014578  0.162490 -0.084570  1.000000 -0.088628 -0.032855
# pdays    -0.023758  0.003435 -0.093044 -0.001565 -0.088628  1.000000  0.454820
# previous  0.001288  0.016674 -0.051710  0.001203 -0.032855  0.454820  1.000000

# %% [markdown]
# ## Target encoding
#
# Now we want to encode the y variable.
# Let's replace the values yes/no with 1/0.

# %%
df_selected.y.head()
# Out:
# 0    no
# 1    no
# 2    no
# 3    no
# 4    no
# Name: y, dtype: object

# %%
(df_selected.y == 'yes').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: y, dtype: bool

# %%
df_selected.y = (df_selected.y == 'yes').astype(int)
df_selected.head()
# Out:
#    age           job  marital  education  balance housing  contact  day month  \
# 0   58    management  married   tertiary     2143     yes  unknown    5   may
# 1   44    technician   single  secondary       29     yes  unknown    5   may
# 2   33  entrepreneur  married  secondary        2     yes  unknown    5   may
# 3   47   blue-collar  married    unknown     1506     yes  unknown    5   may
# 4   33       unknown   single    unknown        1      no  unknown    5   may
#
#    duration  campaign  pdays  previous poutcome  y
# 0       261         1     -1         0  unknown  0
# 1       151         1     -1         0  unknown  0
# 2        76         1     -1         0  unknown  0
# 3        92         1     -1         0  unknown  0
# 4       198         1     -1         0  unknown  0

# %% [markdown]
# ## Split the data
#
# Split your data in train/val/test sets with 60%/20%/20% distribution.
# Use Scikit-Learn for that (the train_test_split function) and set the seed to 42.
# Make sure that the target value y is not in your dataframe.

# %%
from sklearn.model_selection import train_test_split

# %%
df_full_train, df_test = train_test_split(df_selected, test_size = 0.2, random_state = 42)

# %%
len(df_full_train), len(df_test)
# Out:
# (36168, 9043)

# %%
df_train, df_val = train_test_split(df_full_train, test_size = 0.25, random_state = 42)
len(df_train), len(df_val)
# Out:
# (27126, 9042)

# %%
y_train = df_train.y.values
y_val = df_val.y.values
y_test = df_test.y.values

# %%
del df_train["y"]
del df_val["y"]
del df_test["y"]

# %%
df_full_train.y.value_counts(normalize= True)
# Out:
# y
# 0    0.883931
# 1    0.116069
# Name: proportion, dtype: float64

# %% [markdown]
# ### Churn rate

# %%
global_churn_rate = df_full_train.y.mean() 
round(global_churn_rate, 2)
# Out:
# 0.12

# %%
categorical = list(df_full_train.dtypes[df_full_train.dtypes == 'object'].index)

# %%
df_full_train[categorical].nunique()
# Out:
# job          12
# marital       3
# education     4
# housing       2
# contact       3
# month        12
# poutcome      4
# dtype: int64

# %%
df_full_train.head()
# Out:
#        age          job  marital  education  balance housing   contact  day  \
# 3344    41  blue-collar  married    primary      849     yes   unknown   15
# 17965   49   technician  married    primary     1415     yes  cellular   30
# 18299   42       admin.  married  secondary     3842      no  cellular   31
# 10221   37   management   single   tertiary     -119     yes   unknown   11
# 32192   56  blue-collar  married    primary     3498      no  cellular   15
#
#       month  duration  campaign  pdays  previous poutcome  y
# 3344    may        72         1     -1         0  unknown  0
# 17965   jul       269         2     -1         0  unknown  0
# 18299   jul       130         4     -1         0  unknown  0
# 10221   jun       375        11     -1         0  unknown  0
# 32192   apr       264         2     -1         0  unknown  1

# %%
churn_housing = df_full_train[df_full_train.housing == 'yes'].y.mean()
round(churn_housing, 2)
# Out:
# 0.08

# %%
churn_no_housing = df_full_train[df_full_train.housing == 'no'].y.mean()
round(churn_no_housing, 2)
# Out:
# 0.17

# %% [markdown]
# ## Risk ratio

# %%
round(churn_housing/global_churn_rate, 2)
# Out:
# 0.65

# %%
round(churn_no_housing/global_churn_rate, 2)
# Out:
# 1.43

# %% [markdown]
# $\mathrm{risk{\ }ratio} = \frac{\mathrm{group{\ }churn{\ }rate}}{\mathrm{global{\ }churn{\ }rate}}$

# %% [markdown]
# $\mathrm{risk{\ }ratio} > 1 \implies$ high risk of churning
#
# $\mathrm{risk{\ }ratio} < 1 \implies$ low risk of churning

# %% [markdown]
# Here, we see that people without housing are at a very high risk of churning

# %%
from IPython.display import display

# %%
for c in categorical:
    df_group = df_full_train.groupby(c).y.agg(['mean', 'count'])
    df_group['diff'] = df_group['mean'] - global_churn_rate
    df_group['risk'] = df_group['mean']/global_churn_rate
    display(df_group)
    print()
    print()
# Out:
#                    mean  count      diff      risk
# job
# admin.         0.119894   4137  0.003824  1.032947
# blue-collar    0.072252   7806 -0.043817  0.622490
# entrepreneur   0.086587   1178 -0.029482  0.745997
# housemaid      0.093812   1002 -0.022257  0.808243
# management     0.135467   7500  0.019397  1.167117
# retired        0.222590   1815  0.106520  1.917727
# self-employed  0.122862   1286  0.006792  1.058518
# services       0.090746   3350 -0.025323  0.781827
# student        0.278976    742  0.162906  2.403524
# technician     0.108760   6096 -0.007310  0.937024
# unemployed     0.160313   1023  0.044243  1.381180
# unknown        0.111588    233 -0.004481  0.961390
#               mean  count      diff      risk
# marital
# divorced  0.119720   4143  0.003651  1.031451
# married   0.100578  21804 -0.015492  0.866532
# single    0.147637  10221  0.031568  1.271973
#                mean  count      diff      risk
# education
# ...

# %% [markdown]
# ## Question 3
#
# Calculate the mutual information score between y and other categorical variables in the dataset. Use the training set only.
# Round the scores to 2 decimals using round(score, 2).
# Which of these variables has the biggest mutual information score?
#
# - contact
# - education
# - housing
# - poutcome

# %%
from sklearn.metrics import mutual_info_score

# %%
print(f'The mutual information score between y and contact is {round(mutual_info_score(df_full_train.y, df_full_train.contact),2)}')
print(f'The mutual information score between y and contact is {round(mutual_info_score(df_full_train.y, df_full_train.education),2)}')
print(f'The mutual information score between y and contact is {round(mutual_info_score(df_full_train.y, df_full_train.housing),2)}')
print(f'The mutual information score between y and contact is {round(mutual_info_score(df_full_train.y, df_full_train.poutcome),2)}')
# Out:
# The mutual information score between y and contact is 0.01
# The mutual information score between y and contact is 0.0
# The mutual information score between y and contact is 0.01
# The mutual information score between y and contact is 0.03

# %%
def mutual_info_churn_score(series):
    return round(mutual_info_score(series, df_full_train.y),2)

# %%
mi = df_full_train[categorical].apply(mutual_info_churn_score)
mi.sort_values(ascending = False)
# Out:
# poutcome     0.03
# month        0.02
# job          0.01
# contact      0.01
# housing      0.01
# education    0.00
# marital      0.00
# dtype: float64

# %% [markdown]
# Therefore, the variable with the biggest mutual information score is `poutcome`

# %% [markdown]
# ## Question 4
#
# - Now let's train a logistic regression.
# - Remember that we have several categorical variables in the dataset. Include them using one-hot encoding.
# - Fit the model on the training dataset.
#   - To make sure the results are reproducible across different versions of Scikit-Learn, fit the model with these parameters:
#   - model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
# - Calculate the accuracy on the validation dataset and round it to 2 decimal digits.
# What accuracy did you get?

# %% [markdown]
# ### One-hot encoding

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
train_dicts = df_train[categorical + numerical].to_dict(orient = 'records') # orient = 'records' turns into dictionary row-wise

# %%
dv = DictVectorizer(sparse = False)

# %%
X_train = dv.fit_transform(train_dicts)

# %%
dv.get_feature_names_out()
# Out:
# array(['age', 'balance', 'campaign', 'contact=cellular',
#        'contact=telephone', 'contact=unknown', 'day', 'duration',
#        'education=primary', 'education=secondary', 'education=tertiary',
#        'education=unknown', 'housing=no', 'housing=yes', 'job=admin.',
#        'job=blue-collar', 'job=entrepreneur', 'job=housemaid',
#        'job=management', 'job=retired', 'job=self-employed',
#        'job=services', 'job=student', 'job=technician', 'job=unemployed',
#        'job=unknown', 'marital=divorced', 'marital=married',
#        'marital=single', 'month=apr', 'month=aug', 'month=dec',
#        'month=feb', 'month=jan', 'month=jul', 'month=jun', 'month=mar',
#        'month=may', 'month=nov', 'month=oct', 'month=sep', 'pdays',
#        'poutcome=failure', 'poutcome=other', 'poutcome=success',
#        'poutcome=unknown', 'previous'], dtype=object)

# %%
val_dicts = df_val[categorical + numerical].to_dict(orient = 'records')
X_val = dv.fit_transform(val_dicts)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

# %%
model.intercept_[0]
# Out:
# -0.9714700682173637

# %%
model.coef_[0].round(3)
# Out:
# array([-1.000e-03,  0.000e+00, -8.000e-02,  2.580e-01,  8.100e-02,
#        -1.310e+00,  9.000e-03,  4.000e-03, -4.360e-01, -2.600e-01,
#        -5.400e-02, -2.210e-01, -1.290e-01, -8.420e-01,  7.300e-02,
#        -2.280e-01, -2.660e-01, -3.180e-01, -8.100e-02,  3.060e-01,
#        -3.030e-01, -1.420e-01,  2.740e-01, -1.540e-01,  2.400e-02,
#        -1.570e-01, -3.140e-01, -4.820e-01, -1.760e-01,  1.300e-02,
#        -7.240e-01,  3.640e-01, -3.400e-01, -1.123e+00, -1.023e+00,
#         3.190e-01,  1.430e+00, -5.000e-01, -9.820e-01,  8.060e-01,
#         7.890e-01, -1.000e-03, -8.000e-01, -6.360e-01,  1.482e+00,
#        -1.018e+00,  9.000e-03])

# %%
model.predict(X_val) # hard prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pred = model.predict_proba(X_val)[:,1] # soft prediction

# %%
churn_decision = (y_pred >= 0.5)

# %%
accuracy = (y_val == churn_decision).mean()
print(f'The accuracy on the validation data set is {round(accuracy,2)}.')
# Out:
# The accuracy on the validation data set is 0.9.

# %%
df_pred = pd.DataFrame()
df_pred['probability'] = y_pred
df_pred['prediction'] = churn_decision.astype(int)
df_pred['actual'] = y_val
df_pred['correct'] = df_pred['prediction'] == df_pred['actual'] 
df_pred
# Out:
#       probability  prediction  actual  correct
# 0        0.012978           0       0     True
# 1        0.009960           0       0     True
# 2        0.155134           0       1    False
# 3        0.232160           0       0     True
# 4        0.445793           0       1    False
# ...           ...         ...     ...      ...
# 9037     0.022280           0       0     True
# 9038     0.270474           0       1    False
# 9039     0.050530           0       0     True
# 9040     0.008814           0       0     True
# 9041     0.274692           0       1    False
#
# [9042 rows x 4 columns]

# %% [markdown]
# ## Question 5
#
# - Let's find the least useful feature using the feature elimination technique.
# - Train a model with all these features (using the same parameters as in Q4).
# - Now exclude each feature from this set and train a model without it. Record the accuracy for each model.
# - For each feature, calculate the difference between the original accuracy and the accuracy without the feature.
# Which of following feature has the smallest difference?

# %%
a = [1, 2, 3, 4]
b = 'abcd'

# %%
dict(zip(a,b))
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %%
dict(zip(dv.get_feature_names_out(), model.coef_[0].round(3)))
# Out:
# {'age': -0.001,
#  'balance': 0.0,
#  'campaign': -0.08,
#  'contact=cellular': 0.258,
#  'contact=telephone': 0.081,
#  'contact=unknown': -1.31,
#  'day': 0.009,
#  'duration': 0.004,
#  'education=primary': -0.436,
#  'education=secondary': -0.26,
#  'education=tertiary': -0.054,
#  'education=unknown': -0.221,
#  'housing=no': -0.129,
#  'housing=yes': -0.842,
#  'job=admin.': 0.073,
#  'job=blue-collar': -0.228,
#  'job=entrepreneur': -0.266,
#  'job=housemaid': -0.318,
#  'job=management': -0.081,
#  'job=retired': 0.306,
#  'job=self-employed': -0.303,
#  'job=services': -0.142,
#  'job=student': 0.274,
#  'job=technician': -0.154,
#  'job=unemployed': 0.024,
#  'job=unknown': -0.157,
#  'marital=divorced': -0.314,
#  'marital=married': -0.482,
#  'marital=single': -0.176,
#  'month=apr': 0.013,
#  'month=aug': -0.724,
#  'month=dec': 0.364,
#  'month=feb': -0.34,
#  'month=jan': -1.123,
#  'month=jul': -1.023,
#  'month=jun': 0.319,
#  'month=mar': 1.43,
# ...

# %%
small = ['age', 'balance', 'campaign']

# %%
df_train[small].iloc[:10].to_dict(orient = 'records')
# Out:
# [{'age': 32, 'balance': 1100, 'campaign': 1},
#  {'age': 38, 'balance': 0, 'campaign': 1},
#  {'age': 49, 'balance': 3309, 'campaign': 2},
#  {'age': 37, 'balance': 2410, 'campaign': 1},
#  {'age': 31, 'balance': 3220, 'campaign': 4},
#  {'age': 32, 'balance': 11287, 'campaign': 7},
#  {'age': 35, 'balance': 0, 'campaign': 2},
#  {'age': 39, 'balance': -17, 'campaign': 1},
#  {'age': 60, 'balance': 2934, 'campaign': 2},
#  {'age': 48, 'balance': 3, 'campaign': 2}]

# %%
dicts_train_small = df_train[small].to_dict(orient = 'records')
dicts_val_small = df_val[small].to_dict(orient = 'records')

# %%
dv_small = DictVectorizer(sparse = False)
dv_small.fit(dicts_train_small)
# Out:
# DictVectorizer(sparse=False)

# %%
dv_small.get_feature_names_out()
# Out:
# array(['age', 'balance', 'campaign'], dtype=object)

# %%
X_train_small = dv_small.transform(dicts_train_small)

# %%
model_small = LogisticRegression()
model_small.fit(X_train_small, y_train)
# Out:
# LogisticRegression()

# %%
w0 = model_small.intercept_[0]
w0
# Out:
# -2.051939009497171

# %%
model_small.coef_[0]
# Out:
# array([ 6.18292731e-03,  3.53000137e-05, -1.20770021e-01])

# %%
excluded_features = ['age', 'balance', 'marital', 'previous']
for feature in excluded_features:
    all = categorical + numerical
    small = all
    small.remove(feature)
    dicts_train_small = df_train[small].to_dict(orient = 'records')
    dicts_val_small = df_val[small].to_dict(orient = 'records')
    dv_small = DictVectorizer(sparse = False)
    dv_small.fit(dicts_train_small)
    X_train_small = dv_small.transform(dicts_train_small)
    X_val_small = dv_small.transform(dicts_val_small)
    model_small = LogisticRegression(solver='liblinear', C=1.0, max_iter=1000, random_state=42)
    model_small.fit(X_train_small, y_train)
    y_pred = model_small.predict_proba(X_val_small)[:,1]
    churn_decision = (y_pred >= 0.5)
    accuracy_small = (y_val == churn_decision).mean()
    diff = accuracy - accuracy_small
    print(f'The diffrence between the original accuracy and the accuracy without the feature {feature} is {abs(diff)}.')
# Out:
# The diffrence between the original accuracy and the accuracy without the feature age is 0.0008847600088476293.
# The diffrence between the original accuracy and the accuracy without the feature balance is 0.00044238000442375913.
# The diffrence between the original accuracy and the accuracy without the feature marital is 0.000774165007741634.
# The diffrence between the original accuracy and the accuracy without the feature previous is 0.0.

# %% [markdown]
# ## Question 6
#
# - Now let's train a regularized logistic regression.
# - Let's try the following values of the parameter C: [0.01, 0.1, 1, 10, 100].
# - Train models using all the features as in Q4.
# - Calculate the accuracy on the validation dataset and round it to 3 decimal digits.
#
# Which of these C leads to the best accuracy on the validation set?
#
# - 0.01
# - 0.1
# - 1
# - 10
# - 100

# %%
Cs = [0.01, 0.1, 1, 10, 100]
accuracies = []
for C in Cs:
    train_dicts = df_train[categorical + numerical].to_dict(orient = 'records')
    dv = DictVectorizer(sparse = False)
    X_train = dv.fit_transform(train_dicts)
    val_dicts = df_val[categorical + numerical].to_dict(orient = 'records')
    X_val = dv.fit_transform(val_dicts)
    model = LogisticRegression(solver='liblinear', C=C, max_iter=1000, random_state=42)
    model.fit(X_train, y_train)
    y_pred = model.predict_proba(X_val)[:,1]
    churn_decision = (y_pred >= 0.5)
    accuracy = (y_val == churn_decision).mean()
    accuracies.append(accuracy)
    print(f'The accuracy on validation set using C = {C} is {accuracy.round(3)}.')
# Out:
# The accuracy on validation set using C = 0.01 is 0.898.
# The accuracy on validation set using C = 0.1 is 0.901.
# The accuracy on validation set using C = 1 is 0.901.
# The accuracy on validation set using C = 10 is 0.902.
# The accuracy on validation set using C = 100 is 0.901.

# %%
C_accuracies = dict(zip(Cs, accuracies))
C_accuracies
# Out:
# {0.01: 0.8979208139792081,
#  0.1: 0.9009068790090687,
#  1: 0.9010174740101747,
#  10: 0.9015704490157045,
#  100: 0.9010174740101747}

# %%
df_accuracy = pd.DataFrame()
df_accuracy['C'] = C_accuracies.keys()
df_accuracy['accuracy'] = C_accuracies.values()
df_accuracy.sort_values(by = 'accuracy', ascending = False)
# Out:
#         C  accuracy
# 3   10.00  0.901570
# 4  100.00  0.901017
# 2    1.00  0.901017
# 1    0.10  0.900907
# 0    0.01  0.897921
